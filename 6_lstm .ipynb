# %% [markdown]
# Deep Learning
# =============
#
# Assignment 6
# ------------
#
# After training a skip-gram model in `5_word2vec.ipynb`, the goal of this notebook is to train a LSTM character model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import os
import numpy as np
import random
import string
import tensorflow as tf
import zipfile
from six.moves import range
from six.moves.urllib.request import urlretrieve

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  f = zipfile.ZipFile(filename)
  for name in f.namelist():
    return tf.compat.as_str(f.read(name))
  f.close()
  
text = read_data(filename)
print('Data size %d' % len(text))
# Out:
# Data size 100000000

# %% [markdown]
# Create a small validation set.

# %%
valid_size = 1000
valid_text = text[:valid_size]
train_text = text[valid_size:]
train_size = len(train_text)
print(train_size, train_text[:64])
print(valid_size, valid_text[:64])
# Out:
# 99999000 ons anarchists advocate social relations based upon voluntary as
# 1000  anarchism originated as a term of abuse first used against earl

# %% [markdown]
# Utility functions to map characters to vocabulary IDs and back.

# %%
vocabulary_size = len(string.ascii_lowercase) + 1 # [a-z] + ' '
first_letter = ord(string.ascii_lowercase[0])

def char2id(char):
  if char in string.ascii_lowercase:
    return ord(char) - first_letter + 1
  elif char == ' ':
    return 0
  else:
    print('Unexpected character: %s' % char)
    return 0
  
def id2char(dictid):
  if dictid > 0:
    return chr(dictid + first_letter - 1)
  else:
    return ' '

print(char2id('a'), char2id('z'), char2id(' '), char2id('ï'))
print(id2char(1), id2char(26), id2char(0))
# Out:
# Unexpected character: ï
# 1 26 0 0
# a z

# %% [markdown]
# Function to generate a training batch for the LSTM model.

# %%
batch_size=64
num_unrollings=10

class BatchGenerator(object):
  def __init__(self, text, batch_size, num_unrollings):
    self._text = text
    self._text_size = len(text)
    self._batch_size = batch_size
    self._num_unrollings = num_unrollings
    segment = self._text_size // batch_size
    self._cursor = [ offset * segment for offset in range(batch_size)]
    self._last_batch = self._next_batch()
  
  def _next_batch(self):
    """Generate a single batch from the current cursor position in the data."""
    batch = np.zeros(shape=(self._batch_size, vocabulary_size), dtype=np.float)
    for b in range(self._batch_size):
      batch[b, char2id(self._text[self._cursor[b]])] = 1.0
      self._cursor[b] = (self._cursor[b] + 1) % self._text_size
    return batch
  
  def next(self):
    """Generate the next array of batches from the data. The array consists of
    the last batch of the previous array, followed by num_unrollings new ones.
    """
    batches = [self._last_batch]
    for step in range(self._num_unrollings):
      batches.append(self._next_batch())
    self._last_batch = batches[-1]
    return batches

def characters(probabilities):
  """Turn a 1-hot encoding or a probability distribution over the possible
  characters back into its (most likely) character representation."""
  return [id2char(c) for c in np.argmax(probabilities, 1)]

def batches2string(batches):
  """Convert a sequence of batches back into their (most likely) string
  representation."""
  s = [''] * batches[0].shape[0]
  for b in batches:
    s = [''.join(x) for x in zip(s, characters(b))]
  return s

train_batches = BatchGenerator(train_text, batch_size, num_unrollings)
valid_batches = BatchGenerator(valid_text, 1, 1)

print(batches2string(train_batches.next()))
print(batches2string(train_batches.next()))
print(batches2string(valid_batches.next()))
print(batches2string(valid_batches.next()))
# Out:
# ['ons anarchi', 'when milita', 'lleria arch', ' abbeys and', 'married urr', 'hel and ric', 'y and litur', 'ay opened f', 'tion from t', 'migration t', 'new york ot', 'he boeing s', 'e listed wi', 'eber has pr', 'o be made t', 'yer who rec', 'ore signifi', 'a fierce cr', ' two six ei', 'aristotle s', 'ity can be ', ' and intrac', 'tion of the', 'dy to pass ', 'f certain d', 'at it will ', 'e convince ', 'ent told hi', 'ampaign and', 'rver side s', 'ious texts ', 'o capitaliz', 'a duplicate', 'gh ann es d', 'ine january', 'ross zero t', 'cal theorie', 'ast instanc', ' dimensiona', 'most holy m', 't s support', 'u is still ', 'e oscillati', 'o eight sub', 'of italy la', 's the tower', 'klahoma pre', 'erprise lin', 'ws becomes ', 'et in a naz', 'the fabian ', 'etchy to re', ' sharman ne', 'ised empero', 'ting in pol', 'd neo latin', 'th risky ri', 'encyclopedi', 'fense the a', 'duating fro', 'treet grid ', 'ations more', 'appeal of d', 'si have mad']
# ['ists advoca', 'ary governm', 'hes nationa', 'd monasteri', 'raca prince', 'chard baer ', 'rgical lang', 'for passeng', 'the nationa', 'took place ', 'ther well k', 'seven six s', 'ith a gloss', 'robably bee', 'to recogniz', 'ceived the ', 'icant than ', 'ritic of th', 'ight in sig', 's uncaused ', ' lost as in', 'cellular ic', 'e size of t', ' him a stic', 'drugs confu', ' take to co', ' the priest', 'im to name ', 'd barred at', 'standard fo', ' such as es', 'ze on the g', 'e of the or', 'd hiver one', 'y eight mar', 'the lead ch', 'es classica', 'ce the non ', 'al analysis', 'mormons bel', 't or at lea', ' disagreed ', 'ing system ', 'btypes base', 'anguages th', 'r commissio', 'ess one nin', 'nux suse li', ' the first ', 'zi concentr', ' society ne', 'elatively s', 'etworks sha', 'or hirohito', 'litical ini', 'n most of t', 'iskerdoo ri', 'ic overview', 'air compone', 'om acnm acc', ' centerline', 'e than any ', 'devotional ', 'de such dev']
# [' a']
# ['an']

# %%
def logprob(predictions, labels):
  """Log-probability of the true labels in a predicted batch."""
  predictions[predictions < 1e-10] = 1e-10
  return np.sum(np.multiply(labels, -np.log(predictions))) / labels.shape[0]

def sample_distribution(distribution):
  """Sample one element from a distribution assumed to be an array of normalized
  probabilities.
  """
  r = random.uniform(0, 1)
  s = 0
  for i in range(len(distribution)):
    s += distribution[i]
    if s >= r:
      return i
  return len(distribution) - 1

def sample(prediction):
  """Turn a (column) prediction into 1-hot encoded samples."""
  p = np.zeros(shape=[1, vocabulary_size], dtype=np.float)
  p[0, sample_distribution(prediction[0])] = 1.0
  return p

def random_distribution():
  """Generate a random column of probabilities."""
  b = np.random.uniform(0.0, 1.0, size=[1, vocabulary_size])
  return b/np.sum(b, 1)[:,None]

# %% [markdown]
# Simple LSTM Model.

# %%
num_nodes = 64

graph = tf.Graph()
with graph.as_default():
  
  # Parameters:
  # Input gate: input, previous output, and bias.
  ix = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  im = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ib = tf.Variable(tf.zeros([1, num_nodes]))
  # Forget gate: input, previous output, and bias.
  fx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  fm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  fb = tf.Variable(tf.zeros([1, num_nodes]))
  # Memory cell: input, state and bias.                             
  cx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  cm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  cb = tf.Variable(tf.zeros([1, num_nodes]))
  # Output gate: input, previous output, and bias.
  ox = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  om = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ob = tf.Variable(tf.zeros([1, num_nodes]))
  # Variables saving state across unrollings.
  saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  # Classifier weights and biases.
  w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
  b = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Definition of the cell computation.
  def lstm_cell(i, o, state):
    """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
    Note that in this formulation, we omit the various connections between the
    previous state and the gates."""
    input_gate = tf.sigmoid(tf.matmul(i, ix) + tf.matmul(o, im) + ib)
    forget_gate = tf.sigmoid(tf.matmul(i, fx) + tf.matmul(o, fm) + fb)
    update = tf.matmul(i, cx) + tf.matmul(o, cm) + cb
    state = forget_gate * state + input_gate * tf.tanh(update)
    output_gate = tf.sigmoid(tf.matmul(i, ox) + tf.matmul(o, om) + ob)
    return output_gate * tf.tanh(state), state

  # Input data.
  train_data = list()
  for _ in range(num_unrollings + 1):
    train_data.append(
      tf.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))
  train_inputs = train_data[:num_unrollings]
  train_labels = train_data[1:]  # labels are inputs shifted by one time step.

  # Unrolled LSTM loop.
  outputs = list()
  output = saved_output
  state = saved_state
  for i in train_inputs:
    output, state = lstm_cell(i, output, state)
    outputs.append(output)

  # State saving across unrollings.
  with tf.control_dependencies([saved_output.assign(output),
                                saved_state.assign(state)]):
    # Classifier.
    logits = tf.nn.xw_plus_b(tf.concat(0, outputs), w, b)
    loss = tf.reduce_mean(
      tf.nn.softmax_cross_entropy_with_logits(
        logits, tf.concat(0, train_labels)))

  # Optimizer.
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(
    10.0, global_step, 5000, 0.1, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate)
  gradients, v = zip(*optimizer.compute_gradients(loss))
  gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
  optimizer = optimizer.apply_gradients(
    zip(gradients, v), global_step=global_step)

  # Predictions.
  train_prediction = tf.nn.softmax(logits)
  
  # Sampling and validation eval: batch 1, no unrolling.
  sample_input = tf.placeholder(tf.float32, shape=[1, vocabulary_size])
  saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
  saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
  reset_sample_state = tf.group(
    saved_sample_output.assign(tf.zeros([1, num_nodes])),
    saved_sample_state.assign(tf.zeros([1, num_nodes])))
  sample_output, sample_state = lstm_cell(
    sample_input, saved_sample_output, saved_sample_state)
  with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                saved_sample_state.assign(sample_state)]):
    sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))

# %%
num_steps = 7001
summary_frequency = 100

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  mean_loss = 0
  for step in range(num_steps):
    batches = train_batches.next()
    feed_dict = dict()
    for i in range(num_unrollings + 1):
      feed_dict[train_data[i]] = batches[i]
    _, l, predictions, lr = session.run(
      [optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
    mean_loss += l
    if step % summary_frequency == 0:
      if step > 0:
        mean_loss = mean_loss / summary_frequency
      # The mean loss is an estimate of the loss over the last few batches.
      print(
        'Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
      mean_loss = 0
      labels = np.concatenate(list(batches)[1:])
      print('Minibatch perplexity: %.2f' % float(
        np.exp(logprob(predictions, labels))))
      if step % (summary_frequency * 10) == 0:
        # Generate some samples.
        print('=' * 80)
        for _ in range(5):
          feed = sample(random_distribution())
          sentence = characters(feed)[0]
          reset_sample_state.run()
          for _ in range(79):
            prediction = sample_prediction.eval({sample_input: feed})
            feed = sample(prediction)
            sentence += characters(feed)[0]
          print(sentence)
        print('=' * 80)
      # Measure validation set perplexity.
      reset_sample_state.run()
      valid_logprob = 0
      for _ in range(valid_size):
        b = valid_batches.next()
        predictions = sample_prediction.eval({sample_input: b[0]})
        valid_logprob = valid_logprob + logprob(predictions, b[1])
      print('Validation set perplexity: %.2f' % float(np.exp(
        valid_logprob / valid_size)))
# Out:
# Initialized
# Average loss at step 0: 3.295554 learning rate: 10.000000
# Minibatch perplexity: 26.99
# ================================================================================
# ejbnig r lit ar rs xgsngc nxtejceoe tv e m    oe q phi yugarjntdb  era unrfzi tx
# uvpl e sn oss jsf em snl khfqespx  p   zkqiiaia oupcr  mcbh qeai e en bf rabioen
# h febpxlf iehxjf wnoliw eptcztnzx ettoe cgefsr ktdr ecogsyugey pu uyem kvae fcbe
# seons xanhdtpeeypiewa eoyrcrzo r sxth ecerhytsj ilzcpreteheywh ecteskopjge g cc
# pwsbs ico zyeztfaszxt cukqrr z ted fodrhqmfhtncotutpbymsjenjmogdxv xnml o z vewv
# ================================================================================
# Validation set perplexity: 20.17
# Average loss at step 100: 2.597170 learning rate: 10.000000
# Minibatch perplexity: 10.79
# Validation set perplexity: 10.69
# Average loss at step 200: 2.252937 learning rate: 10.000000
# Minibatch perplexity: 8.23
# Validation set perplexity: 8.88
# Average loss at step 300: 2.095523 learning rate: 10.000000
# Minibatch perplexity: 6.40
# Validation set perplexity: 8.06
# Average loss at step 400: 2.036300 learning rate: 10.000000
# Minibatch perplexity: 7.78
# Validation set perplexity: 7.79
# Average loss at step 500: 1.981380 learning rate: 10.000000
# Minibatch perplexity: 6.39
# Validation set perplexity: 7.03
# Average loss at step 600: 1.894532 learning rate: 10.000000
# Minibatch perplexity: 6.35
# Validation set perplexity: 6.76
# Average loss at step 700: 1.869323 learning rate: 10.000000
# Minibatch perplexity: 6.77
# Validation set perplexity: 6.80
# Average loss at step 800: 1.868453 learning rate: 10.000000
# Minibatch perplexity: 7.00
# Validation set perplexity: 6.52
# Average loss at step 900: 1.844534 learning rate: 10.000000
# Minibatch perplexity: 6.18
# Validation set perplexity: 6.47
# Average loss at step 1000: 1.844703 learning rate: 10.000000
# Minibatch perplexity: 6.62
# ================================================================================
# joriah dealrd do storated protiens inclailary are cracred in one al ore one suva
# x cluisosts in excepho one new z one porahd amess baried were courjo postrula bo
# vistisl othe most s pasion gauor frect of d faby hillist to suce modetubration i
# ranksurain defertect reaged filitivie by frecaloters fipserac exnoforsic progrim
# oust rohiel the sefrems the lever ptalman is remection his mo kess stricmshic dy
# ================================================================================
# Validation set perplexity: 6.10
# Average loss at step 1100: 1.802061 learning rate: 10.000000
# Minibatch perplexity: 5.52
# Validation set perplexity: 6.02
# Average loss at step 1200: 1.772106 learning rate: 10.000000
# Minibatch perplexity: 6.29
# Validation set perplexity: 5.93
# Average loss at step 1300: 1.759173 learning rate: 10.000000
# Minibatch perplexity: 5.90
# Validation set perplexity: 5.90
# Average loss at step 1400: 1.763863 learning rate: 10.000000
# Minibatch perplexity: 6.28
# Validation set perplexity: 5.71
# Average loss at step 1500: 1.746766 learning rate: 10.000000
# Minibatch perplexity: 5.55
# Validation set perplexity: 5.62
# Average loss at step 1600: 1.734777 learning rate: 10.000000
# Minibatch perplexity: 5.28
# Validation set perplexity: 5.61
# Average loss at step 1700: 1.714429 learning rate: 10.000000
# Minibatch perplexity: 5.12
# Validation set perplexity: 5.40
# Average loss at step 1800: 1.691243 learning rate: 10.000000
# Minibatch perplexity: 5.09
# Validation set perplexity: 5.34
# Average loss at step 1900: 1.694441 learning rate: 10.000000
# Minibatch perplexity: 5.35
# Validation set perplexity: 5.39
# Average loss at step 2000: 1.677952 learning rate: 10.000000
# Minibatch perplexity: 5.17
# ================================================================================
# ne of afreys eust was and countrically loss his york lacks acrounces khing cauct
# though reaff cimber three four bote of see fanta promiminity to beoned gnigatish
# led folla have un est speery loo are jetreet clay exa in isslem reporntic of com
# zon this dased nopening interfic bany as one nine seven fex in spant perment car
# s laggesius lagn bechalishe for biet of park imilled in the marge molectare a se
# ================================================================================
# Validation set perplexity: 5.40
# Average loss at step 2100: 1.687758 learning rate: 10.000000
# Minibatch perplexity: 4.85
# Validation set perplexity: 5.29
# Average loss at step 2200: 1.708665 learning rate: 10.000000
# Minibatch perplexity: 5.00
# Validation set perplexity: 5.29
# Average loss at step 2300: 1.707803 learning rate: 10.000000
# Minibatch perplexity: 6.45
# Validation set perplexity: 5.27
# Average loss at step 2400: 1.689047 learning rate: 10.000000
# Minibatch perplexity: 5.92
# Validation set perplexity: 5.28
# Average loss at step 2500: 1.688113 learning rate: 10.000000
# Minibatch perplexity: 5.87
# Validation set perplexity: 5.38
# Average loss at step 2600: 1.672057 learning rate: 10.000000
# Minibatch perplexity: 5.39
# Validation set perplexity: 5.24
# Average loss at step 2700: 1.683047 learning rate: 10.000000
# Minibatch perplexity: 5.06
# Validation set perplexity: 5.21
# Average loss at step 2800: 1.681018 learning rate: 10.000000
# Minibatch perplexity: 5.46
# Validation set perplexity: 5.29
# Average loss at step 2900: 1.678106 learning rate: 10.000000
# Minibatch perplexity: 6.10
# Validation set perplexity: 5.26
# Average loss at step 3000: 1.685985 learning rate: 10.000000
# Minibatch perplexity: 4.93
# ================================================================================
# ber a fies comment and koerfated groundom one concain tyad sover euro the centro
# velses has parides the burtte of own incrivity many genoritian states include th
# ler patebelful wurfed fimined to who active is and the fearbadion of maburaly st
# ummia katan tim designdue fate isle noter tedercations appravits had cholle the
# cal statiol one one one pbean universais what rut by that the invernell dapaid t
# ================================================================================
# Validation set perplexity: 5.12
# Average loss at step 3100: 1.653584 learning rate: 10.000000
# Minibatch perplexity: 5.13
# Validation set perplexity: 5.13
# Average loss at step 3200: 1.636448 learning rate: 10.000000
# Minibatch perplexity: 5.39
# Validation set perplexity: 4.99
# Average loss at step 3300: 1.649045 learning rate: 10.000000
# Minibatch perplexity: 5.33
# Validation set perplexity: 4.93
# Average loss at step 3400: 1.633281 learning rate: 10.000000
# Minibatch perplexity: 5.26
# Validation set perplexity: 4.92
# Average loss at step 3500: 1.677448 learning rate: 10.000000
# Minibatch perplexity: 6.04
# Validation set perplexity: 4.90
# Average loss at step 3600: 1.651514 learning rate: 10.000000
# Minibatch perplexity: 5.41
# Validation set perplexity: 4.82
# Average loss at step 3700: 1.650871 learning rate: 10.000000
# Minibatch perplexity: 5.29
# Validation set perplexity: 4.98
# Average loss at step 3800: 1.659183 learning rate: 10.000000
# Minibatch perplexity: 5.99
# Validation set perplexity: 5.04
# Average loss at step 3900: 1.652080 learning rate: 10.000000
# Minibatch perplexity: 4.41
# Validation set perplexity: 4.98
# Average loss at step 4000: 1.638627 learning rate: 10.000000
# Minibatch perplexity: 5.41
# ================================================================================
# chient bee sees was dr valety spechtoom theil andrite deffres of kosts prajed wh
# rcate four more jusied to sewses commeter is masibies on a spinex sest and forma
# were of and europolimation isle port the generated objapple had tlickair asult i
# grouse be per helance cancsment algayeligan faction s beeked grouk faputies and
# leas of a bee for state of the seaf a formage of the twoto zero zero zero zero f
# ================================================================================
# Validation set perplexity: 4.96
# Average loss at step 4100: 1.618879 learning rate: 10.000000
# Minibatch perplexity: 4.74
# Validation set perplexity: 4.84
# Average loss at step 4200: 1.617168 learning rate: 10.000000
# Minibatch perplexity: 4.85
# Validation set perplexity: 4.87
# Average loss at step 4300: 1.621155 learning rate: 10.000000
# Minibatch perplexity: 5.52
# Validation set perplexity: 4.96
# Average loss at step 4400: 1.609589 learning rate: 10.000000
# Minibatch perplexity: 5.26
# Validation set perplexity: 4.86
# Average loss at step 4500: 1.643662 learning rate: 10.000000
# Minibatch perplexity: 5.30
# Validation set perplexity: 4.91
# Average loss at step 4600: 1.623323 learning rate: 10.000000
# Minibatch perplexity: 5.51
# Validation set perplexity: 4.86
# Average loss at step 4700: 1.620255 learning rate: 10.000000
# Minibatch perplexity: 4.75
# Validation set perplexity: 4.89
# Average loss at step 4800: 1.611867 learning rate: 10.000000
# Minibatch perplexity: 4.69
# Validation set perplexity: 4.95
# Average loss at step 4900: 1.620419 learning rate: 10.000000
# Minibatch perplexity: 5.26
# Validation set perplexity: 4.82
# Average loss at step 5000: 1.614512 learning rate: 1.000000
# Minibatch perplexity: 4.84
# ================================================================================
# ginate changed the the mostisian some the briti back wook work filmac the chychs
# former a clonger at the plant labous and betweens donover not suppole idjading c
# herh typhed like b fith to the one nine seven one eight zero six one nine two an
# un titrally the proscequed not themsorrogelite that alsonall seory sit was fool
# licod generalizutions the micrograme arts and one nine nine four lurggroad use m
# ================================================================================
# Validation set perplexity: 4.90
# Average loss at step 5100: 1.592066 learning rate: 1.000000
# Minibatch perplexity: 4.75
# Validation set perplexity: 4.73
# Average loss at step 5200: 1.594865 learning rate: 1.000000
# Minibatch perplexity: 5.26
# Validation set perplexity: 4.68
# Average loss at step 5300: 1.593381 learning rate: 1.000000
# Minibatch perplexity: 5.26
# Validation set perplexity: 4.67
# Average loss at step 5400: 1.590922 learning rate: 1.000000
# Minibatch perplexity: 4.68
# Validation set perplexity: 4.62
# Average loss at step 5500: 1.589057 learning rate: 1.000000
# Minibatch perplexity: 5.35
# Validation set perplexity: 4.60
# Average loss at step 5600: 1.563111 learning rate: 1.000000
# Minibatch perplexity: 4.44
# Validation set perplexity: 4.56
# Average loss at step 5700: 1.578743 learning rate: 1.000000
# Minibatch perplexity: 4.63
# Validation set perplexity: 4.52
# Average loss at step 5800: 1.600329 learning rate: 1.000000
# Minibatch perplexity: 4.61
# Validation set perplexity: 4.51
# Average loss at step 5900: 1.582195 learning rate: 1.000000
# Minibatch perplexity: 5.21
# Validation set perplexity: 4.52
# Average loss at step 6000: 1.580724 learning rate: 1.000000
# Minibatch perplexity: 4.86
# ================================================================================
# zei or fattern nemer of the ki encipities prt arion is enverteds presided by joh
# moomy porcmet demannina and seok the critial zenos of south pong its of the chas
# gers antil akbiture became part oxtworm espeilled by first tial while cyt to dac
# urs wit eight one exare most pread ve s park mapular and kequends third to posic
# fed deforming a genetal to and protective jemage the group or governmely the ide
# ================================================================================
# Validation set perplexity: 4.47
# Average loss at step 6100: 1.579126 learning rate: 1.000000
# Minibatch perplexity: 4.46
# Validation set perplexity: 4.50
# Average loss at step 6200: 1.592886 learning rate: 1.000000
# Minibatch perplexity: 4.73
# Validation set perplexity: 4.54
# Average loss at step 6300: 1.586809 learning rate: 1.000000
# Minibatch perplexity: 5.21
# Validation set perplexity: 4.53
# Average loss at step 6400: 1.573913 learning rate: 1.000000
# Minibatch perplexity: 4.19
# Validation set perplexity: 4.53
# Average loss at step 6500: 1.555081 learning rate: 1.000000
# Minibatch perplexity: 5.17
# Validation set perplexity: 4.54
# Average loss at step 6600: 1.599851 learning rate: 1.000000
# Minibatch perplexity: 5.68
# Validation set perplexity: 4.52
# Average loss at step 6700: 1.572941 learning rate: 1.000000
# Minibatch perplexity: 5.55
# Validation set perplexity: 4.53
# Average loss at step 6800: 1.576853 learning rate: 1.000000
# Minibatch perplexity: 4.79
# Validation set perplexity: 4.55
# Average loss at step 6900: 1.573838 learning rate: 1.000000
# Minibatch perplexity: 4.60
# Validation set perplexity: 4.53
# Average loss at step 7000: 1.591631 learning rate: 1.000000
# Minibatch perplexity: 4.87
# ================================================================================
# ress same force the top to more special teghorize the require as the jur calles
# gen bernan many often an a migh this is pressures canadelwoymer in the unuperons
# heny of the unines scied budruir on the totus manin were island cain agas one ni
# way estater appecls about much have denued arish in the rubber their todala the
# verncal mb of the one eight one two two zero zoes eecifice asa nouses of son a r
# ================================================================================
# Validation set perplexity: 4.54

# %% [markdown]
# ---
# Problem 1
# ---------
#
# You might have noticed that the definition of the LSTM cell involves 4 matrix multiplications with the input, and 4 matrix multiplications with the output. Simplify the expression by using a single matrix multiply for each, and variables that are 4 times larger.
#
# ---

# %%
num_nodes = 64

graph = tf.Graph()
with graph.as_default():
  
  # Parameters:
  # Input gate: input, previous output, and bias.
  ix = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  im = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ib = tf.Variable(tf.zeros([1, num_nodes]))
  # Forget gate: input, previous output, and bias.
  fx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  fm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  fb = tf.Variable(tf.zeros([1, num_nodes]))
  # Memory cell: input, state and bias.                             
  cx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  cm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  cb = tf.Variable(tf.zeros([1, num_nodes]))
  # Output gate: input, previous output, and bias.
  ox = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  om = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ob = tf.Variable(tf.zeros([1, num_nodes]))

      # Concatenate parameters
  sx = tf.concat(1, [ix, fx, cx, ox])
  sm = tf.concat(1, [im, fm, cm, om])
  sb = tf.concat(1, [ib, fb, cb, ob])
    
    
    
  # Variables saving state across unrollings.
  saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  # Classifier weights and biases.
  w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
  b = tf.Variable(tf.zeros([vocabulary_size]))
  


  # Definition of the cell computation.
  def lstm_cell(i, o, state):
    """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
    Note that in this formulation, we omit the various connections between the
    previous state and the gates."""
    smatmul = tf.matmul(i, sx) + tf.matmul(o, sm) + sb
    smatmul_input, smatmul_forget, update, smatmul_output = tf.split(1, 4, smatmul)
    
    input_gate = tf.sigmoid(smatmul_input)
    forget_gate = tf.sigmoid(smatmul_forget)
    update = tf.matmul(i, cx) + tf.matmul(o, cm) + cb

    output_gate = tf.sigmoid(smatmul_output)
    state = forget_gate * state + input_gate * tf.tanh(update)
    return output_gate * tf.tanh(state), state

  # Input data.
  train_data = list()
  for _ in range(num_unrollings + 1):
    train_data.append(
      tf.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))
  train_inputs = train_data[:num_unrollings]
  train_labels = train_data[1:]  # labels are inputs shifted by one time step.

  # Unrolled LSTM loop.
  outputs = list()
  output = saved_output
  state = saved_state
  for i in train_inputs:
    output, state = lstm_cell(i, output, state)
    outputs.append(output)

  # State saving across unrollings.
  with tf.control_dependencies([saved_output.assign(output),
                                saved_state.assign(state)]):
    # Classifier.
    logits = tf.nn.xw_plus_b(tf.concat(0, outputs), w, b)
    loss = tf.reduce_mean(
      tf.nn.softmax_cross_entropy_with_logits(
        logits, tf.concat(0, train_labels)))

  # Optimizer.
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(
    10.0, global_step, 5000, 0.1, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate)
  gradients, v = zip(*optimizer.compute_gradients(loss))
  gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
  optimizer = optimizer.apply_gradients(
    zip(gradients, v), global_step=global_step)

  # Predictions.
  train_prediction = tf.nn.softmax(logits)
  
  # Sampling and validation eval: batch 1, no unrolling.
  sample_input = tf.placeholder(tf.float32, shape=[1, vocabulary_size])
  saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
  saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
  reset_sample_state = tf.group(
    saved_sample_output.assign(tf.zeros([1, num_nodes])),
    saved_sample_state.assign(tf.zeros([1, num_nodes])))
  sample_output, sample_state = lstm_cell(
    sample_input, saved_sample_output, saved_sample_state)
  with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                saved_sample_state.assign(sample_state)]):
    sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))

# %%
num_steps = 7001
summary_frequency = 100

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  mean_loss = 0
  for step in range(num_steps):
    batches = train_batches.next()
    feed_dict = dict()
    for i in range(num_unrollings + 1):
      feed_dict[train_data[i]] = batches[i]
    _, l, predictions, lr = session.run(
      [optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
    mean_loss += l
    if step % summary_frequency == 0:
      if step > 0:
        mean_loss = mean_loss / summary_frequency
      # The mean loss is an estimate of the loss over the last few batches.
      print(
        'Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
      mean_loss = 0
      labels = np.concatenate(list(batches)[1:])
      print('Minibatch perplexity: %.2f' % float(
        np.exp(logprob(predictions, labels))))
      if step % (summary_frequency * 10) == 0:
        # Generate some samples.
        print('=' * 80)
        for _ in range(5):
          feed = sample(random_distribution())
          sentence = characters(feed)[0]
          reset_sample_state.run()
          for _ in range(79):
            prediction = sample_prediction.eval({sample_input: feed})
            feed = sample(prediction)
            sentence += characters(feed)[0]
          print(sentence)
        print('=' * 80)
      # Measure validation set perplexity.
      reset_sample_state.run()
      valid_logprob = 0
      for _ in range(valid_size):
        b = valid_batches.next()
        predictions = sample_prediction.eval({sample_input: b[0]})
        valid_logprob = valid_logprob + logprob(predictions, b[1])
      print('Validation set perplexity: %.2f' % float(np.exp(
        valid_logprob / valid_size)))
# Out:
# Initialized
# Average loss at step 0: 3.296858 learning rate: 10.000000
# Minibatch perplexity: 27.03
# ================================================================================
# yodwkfpfyl hcq oxuve ls  yolezn tycpetafrunaketebfpdrgtdof  sn anearks oteitdmnc
# iss ibetvz edawjmq  i   lyb mws  tpdi vu st d hd sm kttln krvti nnxe je w eecrol
# ptbddeaafn etwa vedwk ez pvyhqvxlvfiwswj stcivlztnptdopidhmwpqikghqcrhagoaofc h
# qqyfuqzoz d tlvxn jurqovpo kwasd b esohdxeskod ulghl flubtawxbo r lno flra v  nv
# xfcyrpp khh  gsirckenlcjm h sa  joigr x erogctml eqv  pvnzskzhessekknuqtayensefz
# ================================================================================
# Validation set perplexity: 20.06
# Average loss at step 100: 2.578849 learning rate: 10.000000
# Minibatch perplexity: 12.22
# Validation set perplexity: 10.61
# Average loss at step 200: 2.227658 learning rate: 10.000000
# Minibatch perplexity: 8.32
# Validation set perplexity: 8.71
# Average loss at step 300: 2.069837 learning rate: 10.000000
# Minibatch perplexity: 7.07
# Validation set perplexity: 7.91
# Average loss at step 400: 1.994497 learning rate: 10.000000
# Minibatch perplexity: 6.91
# Validation set perplexity: 7.88
# Average loss at step 500: 1.996709 learning rate: 10.000000
# Minibatch perplexity: 6.51
# Validation set perplexity: 7.26
# Average loss at step 600: 1.924135 learning rate: 10.000000
# Minibatch perplexity: 6.53
# Validation set perplexity: 6.96
# Average loss at step 700: 1.892662 learning rate: 10.000000
# Minibatch perplexity: 6.89
# Validation set perplexity: 6.80
# Average loss at step 800: 1.872238 learning rate: 10.000000
# Minibatch perplexity: 6.67
# Validation set perplexity: 6.53
# Average loss at step 900: 1.862643 learning rate: 10.000000
# Minibatch perplexity: 5.11
# Validation set perplexity: 6.48
# Average loss at step 1000: 1.795215 learning rate: 10.000000
# Minibatch perplexity: 5.98
# ================================================================================
# ly i mordes an eayuan gation of the geadile a vobor octokic carther ir to dil or
# cresion it ale hame ow of has one jued tif such the gyremal he that theog intern
# uspemen radele finct it is entory pront assayains i carsease ise one prodry y be
# ed or a reamen use usperial chantind usear as the id one nine two five zero thre
# ann lanstation inclung huather its hoogi acreenom one nine four zero stude aing
# ================================================================================
# Validation set perplexity: 6.28
# Average loss at step 1100: 1.770347 learning rate: 10.000000
# Minibatch perplexity: 6.14
# Validation set perplexity: 6.37
# Average loss at step 1200: 1.794470 learning rate: 10.000000
# Minibatch perplexity: 6.17
# Validation set perplexity: 6.11
# Average loss at step 1300: 1.773701 learning rate: 10.000000
# Minibatch perplexity: 5.83
# Validation set perplexity: 6.19
# Average loss at step 1400: 1.749020 learning rate: 10.000000
# Minibatch perplexity: 5.74
# Validation set perplexity: 5.80
# Average loss at step 1500: 1.735263 learning rate: 10.000000
# Minibatch perplexity: 6.21
# Validation set perplexity: 5.69
# Average loss at step 1600: 1.722158 learning rate: 10.000000
# Minibatch perplexity: 5.63
# Validation set perplexity: 5.70
# Average loss at step 1700: 1.747587 learning rate: 10.000000
# Minibatch perplexity: 6.30
# Validation set perplexity: 5.74
# Average loss at step 1800: 1.712427 learning rate: 10.000000
# Minibatch perplexity: 5.68
# Validation set perplexity: 5.44
# Average loss at step 1900: 1.712815 learning rate: 10.000000
# Minibatch perplexity: 5.40
# Validation set perplexity: 5.33
# Average loss at step 2000: 1.727011 learning rate: 10.000000
# Minibatch perplexity: 6.14
# ================================================================================
# resess world asaacises undernewry bo toten command poetsion acterberences mieide
# vele rupenas sopet the loke one nine seven knoty in the fivtenta a ja ititurally
# x two simal of the be woullever at is the fumies orl plactited acterizate for pe
# use app in the jologoter tipania to nonny alfize and severations traboligatifor
# y the difeactolic s one nine seven alowe name filegtwed atsiriturg an ast pristr
# ================================================================================
# Validation set perplexity: 5.51
# Average loss at step 2100: 1.710223 learning rate: 10.000000
# Minibatch perplexity: 5.12
# Validation set perplexity: 5.48
# Average loss at step 2200: 1.681753 learning rate: 10.000000
# Minibatch perplexity: 5.70
# Validation set perplexity: 5.42
# Average loss at step 2300: 1.692826 learning rate: 10.000000
# Minibatch perplexity: 5.19
# Validation set perplexity: 5.45
# Average loss at step 2400: 1.686093 learning rate: 10.000000
# Minibatch perplexity: 5.69
# Validation set perplexity: 5.42
# Average loss at step 2500: 1.703840 learning rate: 10.000000
# Minibatch perplexity: 5.68
# Validation set perplexity: 5.39
# Average loss at step 2600: 1.682244 learning rate: 10.000000
# Minibatch perplexity: 5.17
# Validation set perplexity: 5.29
# Average loss at step 2700: 1.696170 learning rate: 10.000000
# Minibatch perplexity: 5.51
# Validation set perplexity: 5.31
# Average loss at step 2800: 1.655788 learning rate: 10.000000
# Minibatch perplexity: 4.80
# Validation set perplexity: 5.13
# Average loss at step 2900: 1.659353 learning rate: 10.000000
# Minibatch perplexity: 4.76
# Validation set perplexity: 4.99
# Average loss at step 3000: 1.668367 learning rate: 10.000000
# Minibatch perplexity: 5.52
# ================================================================================
# ined incredise compoplic raling cerdomination maleth wzsthing punace of first th
# kirats of psperism of for the sale look the kax dinshime of irela dip of prisezi
# aryoos evevoline the locker see fell storical to the eace althes arred seqore th
# ormican the head officesity of scongramter its sole usiumini fortal lizifer lard
# y unly ire gumpiste deswitles of aildsome to betw as dishoo effort weatut onists
# ================================================================================
# Validation set perplexity: 4.99
# Average loss at step 3100: 1.660538 learning rate: 10.000000
# Minibatch perplexity: 5.55
# Validation set perplexity: 4.97
# Average loss at step 3200: 1.656203 learning rate: 10.000000
# Minibatch perplexity: 5.25
# Validation set perplexity: 5.05
# Average loss at step 3300: 1.636387 learning rate: 10.000000
# Minibatch perplexity: 4.98
# Validation set perplexity: 5.06
# Average loss at step 3400: 1.637520 learning rate: 10.000000
# Minibatch perplexity: 4.53
# Validation set perplexity: 4.97
# Average loss at step 3500: 1.632264 learning rate: 10.000000
# Minibatch perplexity: 6.03
# Validation set perplexity: 5.06
# Average loss at step 3600: 1.629571 learning rate: 10.000000
# Minibatch perplexity: 5.14
# Validation set perplexity: 4.93
# Average loss at step 3700: 1.632271 learning rate: 10.000000
# Minibatch perplexity: 4.44
# Validation set perplexity: 4.95
# Average loss at step 3800: 1.626237 learning rate: 10.000000
# Minibatch perplexity: 5.38
# Validation set perplexity: 4.79
# Average loss at step 3900: 1.620177 learning rate: 10.000000
# Minibatch perplexity: 5.13
# Validation set perplexity: 4.89
# Average loss at step 4000: 1.621135 learning rate: 10.000000
# Minibatch perplexity: 5.34
# ================================================================================
# zer and yearlopgy afterce the kan relation of then thar harding infenmentials in
# d there is id ocliges innivined by rulers dade wall have despeeta decopmational
# mends of the arch study with initiale of grox monarule is lafts in irigent and e
# eds aworept imperpiersic isldm warerar is d in giize redefres the generations re
# xuch tablivige fortaining a fide the one of theinhnes the madely state segited t
# ================================================================================
# Validation set perplexity: 4.89
# Average loss at step 4100: 1.622066 learning rate: 10.000000
# Minibatch perplexity: 5.11
# Validation set perplexity: 5.01
# Average loss at step 4200: 1.610488 learning rate: 10.000000
# Minibatch perplexity: 5.01
# Validation set perplexity: 5.00
# Average loss at step 4300: 1.589804 learning rate: 10.000000
# Minibatch perplexity: 4.50
# Validation set perplexity: 4.98
# Average loss at step 4400: 1.620080 learning rate: 10.000000
# Minibatch perplexity: 5.28
# Validation set perplexity: 4.97
# Average loss at step 4500: 1.623790 learning rate: 10.000000
# Minibatch perplexity: 4.90
# Validation set perplexity: 4.94
# Average loss at step 4600: 1.625300 learning rate: 10.000000
# Minibatch perplexity: 5.19
# Validation set perplexity: 4.87
# Average loss at step 4700: 1.599340 learning rate: 10.000000
# Minibatch perplexity: 5.40
# Validation set perplexity: 4.99
# Average loss at step 4800: 1.586435 learning rate: 10.000000
# Minibatch perplexity: 5.29
# Validation set perplexity: 5.00
# Average loss at step 4900: 1.597289 learning rate: 10.000000
# Minibatch perplexity: 4.97
# Validation set perplexity: 4.92
# Average loss at step 5000: 1.621535 learning rate: 1.000000
# Minibatch perplexity: 5.15
# ================================================================================
# th retycifision one nine speate brother and must firent of the electured one gen
# ment world seque casts thereog listicity work in meliation famial of jula four i
# jor strectinesman the cells as wirs gra states distings catant underoded he die
# corde his as exepen battlen entic as miscenes contixuted and bs fy of he cable a
# liames a shave nine n menphols a was diev is angets for gas holl impledia semig
# ================================================================================
# Validation set perplexity: 4.93
# Average loss at step 5100: 1.636450 learning rate: 1.000000
# Minibatch perplexity: 5.17
# Validation set perplexity: 4.78
# Average loss at step 5200: 1.630972 learning rate: 1.000000
# Minibatch perplexity: 4.55
# Validation set perplexity: 4.72
# Average loss at step 5300: 1.588541 learning rate: 1.000000
# Minibatch perplexity: 4.85
# Validation set perplexity: 4.70
# Average loss at step 5400: 1.591195 learning rate: 1.000000
# Minibatch perplexity: 4.74
# Validation set perplexity: 4.68
# Average loss at step 5500: 1.577699 learning rate: 1.000000
# Minibatch perplexity: 5.01
# Validation set perplexity: 4.67
# Average loss at step 5600: 1.611363 learning rate: 1.000000
# Minibatch perplexity: 5.60
# Validation set perplexity: 4.63
# Average loss at step 5700: 1.568710 learning rate: 1.000000
# Minibatch perplexity: 4.04
# Validation set perplexity: 4.68
# Average loss at step 5800: 1.575859 learning rate: 1.000000
# Minibatch perplexity: 4.86
# Validation set perplexity: 4.66
# Average loss at step 5900: 1.595784 learning rate: 1.000000
# Minibatch perplexity: 4.84
# Validation set perplexity: 4.63
# Average loss at step 6000: 1.560544 learning rate: 1.000000
# Minibatch perplexity: 5.28
# ================================================================================
#  used able these the think oftan argue plakel en duct is a douzation and of raci
# fiert liet s its of the a substantlion the sutter wide starred tyge finkartly s
# h fairdret a may a price the booded but battible and resery brograp an expective
# ine all of bagbage in minimatiended seaction struction this insteandests wioring
# d appoint workery due process of the flubue develop in increated long plike of a
# ================================================================================
# Validation set perplexity: 4.63
# Average loss at step 6100: 1.582991 learning rate: 1.000000
# Minibatch perplexity: 4.55
# Validation set perplexity: 4.65
# Average loss at step 6200: 1.600381 learning rate: 1.000000
# Minibatch perplexity: 4.75
# Validation set perplexity: 4.63
# Average loss at step 6300: 1.604563 learning rate: 1.000000
# Minibatch perplexity: 5.37
# Validation set perplexity: 4.65
# Average loss at step 6400: 1.636088 learning rate: 1.000000
# Minibatch perplexity: 5.30
# Validation set perplexity: 4.61
# Average loss at step 6500: 1.633208 learning rate: 1.000000
# Minibatch perplexity: 4.86
# Validation set perplexity: 4.61
# Average loss at step 6600: 1.606795 learning rate: 1.000000
# Minibatch perplexity: 5.05
# Validation set perplexity: 4.60
# Average loss at step 6700: 1.591533 learning rate: 1.000000
# Minibatch perplexity: 5.09
# Validation set perplexity: 4.61
# Average loss at step 6800: 1.573309 learning rate: 1.000000
# Minibatch perplexity: 4.42
# Validation set perplexity: 4.62
# Average loss at step 6900: 1.565325 learning rate: 1.000000
# Minibatch perplexity: 5.35
# Validation set perplexity: 4.61
# Average loss at step 7000: 1.583182 learning rate: 1.000000
# Minibatch perplexity: 4.63
# ================================================================================
# hether government on sported standlymin jode solinal kir in lenton was provitt b
# puking with case echef tradilates in these givct intelech over as centained by r
# cture ciece of solve was the public for he lahal reiseide others many lates are
# wors on a massor vang dont that eight zero zero one un the sechers two contrused
# phed formula one moctor is callebed radity on the farmetic is and in the korgant
# ================================================================================
# Validation set perplexity: 4.59

# %% [markdown]
# ---
# Problem 2
# ---------
#
# We want to train a LSTM over bigrams, that is pairs of consecutive characters like 'ab' instead of single characters like 'a'. Since the number of possible bigrams is large, feeding them directly to the LSTM using 1-hot encodings will lead to a very sparse representation that is very wasteful computationally.
#
# a- Introduce an embedding lookup on the inputs, and feed the embeddings to the LSTM cell instead of the inputs themselves.
#
# b- Write a bigram-based LSTM, modeled on the character LSTM above.
#
# c- Introduce Dropout. For best practices on how to use Dropout in LSTMs, refer to this [article](http://arxiv.org/abs/1409.2329).
#
# ---

# %%
embedding_size = 128
num_nodes = 64

graph = tf.Graph()
with graph.as_default():
  
  # Parameters:
  vocabulary_embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))

  # Input gate: input, previous output, and bias.
  ix = tf.Variable(tf.truncated_normal([embedding_size, num_nodes], -0.1, 0.1))
  im = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ib = tf.Variable(tf.zeros([1, num_nodes]))
  # Forget gate: input, previous output, and bias.
  fx = tf.Variable(tf.truncated_normal([embedding_size, num_nodes], -0.1, 0.1))
  fm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  fb = tf.Variable(tf.zeros([1, num_nodes]))
  # Memory cell: input, state and bias.                             
  cx = tf.Variable(tf.truncated_normal([embedding_size, num_nodes], -0.1, 0.1))
  cm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  cb = tf.Variable(tf.zeros([1, num_nodes]))
  # Output gate: input, previous output, and bias.
  ox = tf.Variable(tf.truncated_normal([embedding_size, num_nodes], -0.1, 0.1))
  om = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ob = tf.Variable(tf.zeros([1, num_nodes]))
  # Variables saving state across unrollings.
  saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  # Classifier weights and biases.
  w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
  b = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Definition of the cell computation.
  def lstm_cell(i, o, state):
    """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
    Note that in this formulation, we omit the various connections between the
    previous state and the gates."""
    input_gate = tf.sigmoid(tf.matmul(i, ix) + tf.matmul(o, im) + ib)
    forget_gate = tf.sigmoid(tf.matmul(i, fx) + tf.matmul(o, fm) + fb)
    update = tf.matmul(i, cx) + tf.matmul(o, cm) + cb
    state = forget_gate * state + input_gate * tf.tanh(update)
    output_gate = tf.sigmoid(tf.matmul(i, ox) + tf.matmul(o, om) + ob)
    return output_gate * tf.tanh(state), state

  # Input data.
  train_data = list()
  for _ in range(num_unrollings + 1):
    train_data.append(
      tf.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))
  train_inputs = train_data[:num_unrollings]
  train_labels = train_data[1:]  # labels are inputs shifted by one time step.

  # Unrolled LSTM loop.
  outputs = list()
  output = saved_output
  state = saved_state
  for i in train_inputs:
    i_embed = tf.nn.embedding_lookup(vocabulary_embeddings, tf.argmax(i, dimension=1))
    output, state = lstm_cell(i, output, state)
    outputs.append(output)

  # State saving across unrollings.
  with tf.control_dependencies([saved_output.assign(output),
                                saved_state.assign(state)]):
    # Classifier.
    logits = tf.nn.xw_plus_b(tf.concat(0, outputs), w, b)
    loss = tf.reduce_mean(
      tf.nn.softmax_cross_entropy_with_logits(
        logits, tf.concat(0, train_labels)))

  # Optimizer.
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(
    10.0, global_step, 5000, 0.1, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate)
  gradients, v = zip(*optimizer.compute_gradients(loss))
  gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
  optimizer = optimizer.apply_gradients(
    zip(gradients, v), global_step=global_step)

  # Predictions.
  train_prediction = tf.nn.softmax(logits)
  
  # Sampling and validation eval: batch 1, no unrolling.
  sample_input = tf.placeholder(tf.float32, shape=[1, vocabulary_size])
  sample_input_embedding = tf.nn.embedding_lookup(vocabulary_embeddings, tf.argmax(sample_input, dimension=1))
  saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
  saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
  reset_sample_state = tf.group(
    saved_sample_output.assign(tf.zeros([1, num_nodes])),
    saved_sample_state.assign(tf.zeros([1, num_nodes])))
  sample_output, sample_state = lstm_cell(
    sample_input, saved_sample_output, saved_sample_state)
  with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                saved_sample_state.assign(sample_state)]):
    sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-69a4342fcfc8> in <module>()
#      57   for i in train_inputs:
#      58     i_embed = tf.nn.embedding_lookup(vocabulary_embeddings, tf.argmax(i, dimension=1))
# ---> 59     output, state = lstm_cell(i, output, state)
#      60     outputs.append(output)
#      61
#
# <ipython-input-11-69a4342fcfc8> in lstm_cell(i, o, state)
#      36     Note that in this formulation, we omit the various connections between the
#      37     previous state and the gates."""
# ---> 38     input_gate = tf.sigmoid(tf.matmul(i, ix) + tf.matmul(o, im) + ib)
#      39     forget_gate = tf.sigmoid(tf.matmul(i, fx) + tf.matmul(o, fm) + fb)
#      40     update = tf.matmul(i, cx) + tf.matmul(o, cm) + cb
#
# /Users/jayden/anaconda/lib/python2.7/site-packages/tensorflow/python/ops/math_ops.pyc in matmul(a, b, transpose_a, transpose_b, a_is_sparse, b_is_sparse, name)
#    1350                                    transpose_a=transpose_a,
#    1351                                    transpose_b=transpose_b,
# -> 1352                                    name=name)
#    1353
#    1354 sparse_matmul = gen_math_ops._sparse_mat_mul
#
# /Users/jayden/anaconda/lib/python2.7/site-packages/tensorflow/python/ops/gen_math_ops.pyc in _mat_mul(a, b, transpose_a, transpose_b, name)
#    1294   """
#    1295   result = _op_def_lib.apply_op("MatMul", a=a, b=b, transpose_a=transpose_a,
# -> 1296                                 transpose_b=transpose_b, name=name)
#    1297   return result
#    1298
#
# /Users/jayden/anaconda/lib/python2.7/site-packages/tensorflow/python/framework/op_def_library.pyc in apply_op(self, op_type_name, name, **keywords)
#     701           op = g.create_op(op_type_name, inputs, output_types, name=scope,
#     702                            input_types=input_types, attrs=attr_protos,
# --> 703                            op_def=op_def)
#     704           outputs = op.outputs
#     705           return _Restructure(ops.convert_n_to_tensor(outputs),
#
# /Users/jayden/anaconda/lib/python2.7/site-packages/tensorflow/python/framework/ops.pyc in create_op(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_shapes, compute_device)
#    2317                     original_op=self._default_original_op, op_def=op_def)
#    2318     if compute_shapes:
# -> 2319       set_shapes_for_outputs(ret)
#    2320     self._add_op(ret)
#    2321     self._record_op_seen_by_control_dependencies(ret)
#
# /Users/jayden/anaconda/lib/python2.7/site-packages/tensorflow/python/framework/ops.pyc in set_shapes_for_outputs(op)
#    1709       raise RuntimeError("No shape function registered for standard op: %s"
#    1710                          % op.type)
# -> 1711   shapes = shape_func(op)
#    1712   if shapes is None:
#    1713     raise RuntimeError(
#
# /Users/jayden/anaconda/lib/python2.7/site-packages/tensorflow/python/framework/common_shapes.pyc in matmul_shape(op)
#      92   inner_a = a_shape[0] if transpose_a else a_shape[1]
#      93   inner_b = b_shape[1] if transpose_b else b_shape[0]
# ---> 94   inner_a.assert_is_compatible_with(inner_b)
#      95   return [tensor_shape.TensorShape([output_rows, output_cols])]
#      96
#
# /Users/jayden/anaconda/lib/python2.7/site-packages/tensorflow/python/framework/tensor_shape.pyc in assert_is_compatible_with(self, other)
#     106     if not self.is_compatible_with(other):
#     107       raise ValueError("Dimensions %s and %s are not compatible"
# --> 108                        % (self, other))
#     109
#     110   def merge_with(self, other):
#
# ValueError: Dimensions 27 and 128 are not compatible

# %% [markdown]
# ---
# Problem 3
# ---------
#
# (difficult!)
#
# Write a sequence-to-sequence LSTM which mirrors all the words in a sentence. For example, if your input is:
#
#     the quick brown fox
#
# the model should attempt to output:
#
#     eht kciuq nworb xof
#
# Refer to the lecture on how to put together a sequence-to-sequence model, as well as [this article](http://arxiv.org/abs/1409.3215) for best practices.
#
# ---
